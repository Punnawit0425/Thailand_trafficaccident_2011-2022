# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv')
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11640\4179696218.py:1: DtypeWarning: Columns (0: accident_date) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/data.csv')
#               accident_date official_death_date   age  gender nationality  \
# 0       2011-01-01 00:25:00          2011-01-01  21.0    Male        Thai
# 1       2011-01-01 06:35:00          2011-01-01  23.0    Male        Thai
# 2       2011-01-01 19:00:00          2011-01-01  26.0    Male        Thai
# 3       2011-01-01 02:00:00          2011-01-01  16.0    Male        Thai
# 4       2011-01-01 02:00:00          2011-01-01  12.0    Male        Thai
# ...                     ...                 ...   ...     ...         ...
# 240919                  NaN          2022-01-03  30.0    Male     Unknown
# 240920                  NaN          2022-01-03  74.0  Female     Unknown
# 240921                  NaN          2022-01-02  43.0  Female     Unknown
# ...

# %%
df.head()       # first 5 rows
df.tail()       # last 5 rows
df.sample(5)    # 5 random rows
# Out:
#               accident_date official_death_date   age  gender nationality  \
# 17429                   NaN          2011-04-18  56.0    Male        Thai
# 169269  2019-04-20 11:00:00          2019-04-20  21.0    Male        Thai
# 44742   2013-11-03 05:10:00          2013-11-03  40.0  Female        Thai
# 90442   2015-02-26 19:21:00          2015-03-02  42.0    Male     Unknown
# 101554                  NaN          2015-08-24  24.0    Male     Unknown
#
#        accident_cause_code                                     accident_cause  \
# 17429                 V892  Person injured in unspecified motor-vehicle ac...
# 169269                V892  Person injured in unspecified motor-vehicle ac...
# 44742                 V892  Person injured in unspecified motor-vehicle ac...
# 90442                 V285  Motorcycle rider injured in noncollision trans...
# 101554                V289  Motorcycle rider injured in noncollision trans...
#
# ...

# %%
df.shape
# Out:
# (240924, 16)

# %%
df.info()       # column names, data types, how many non-null values
df.dtypes       # just the data types
df.columns      # just the column names
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 240924 entries, 0 to 240923
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   accident_date        106950 non-null  str
#  1   official_death_date  240924 non-null  str
#  2   age                  211110 non-null  float64
#  3   gender               240924 non-null  str
#  4   nationality          240924 non-null  str
#  5   accident_cause_code  240924 non-null  str
#  6   accident_cause       240924 non-null  str
#  7   vehicle_type         240924 non-null  str
#  8   province_th          240924 non-null  str
#  9   district_th          240924 non-null  str
#  10  sub_district_th      240924 non-null  str
#  11  province_en          240924 non-null  str
#  12  district_en          240924 non-null  str
#  13  sub_district_en      240924 non-null  str
#  14  latitude             240924 non-null  float64
# ...

# %%
df.isnull().sum()    # count of missing values per column
# Out:
# accident_date          133974
# official_death_date         0
# age                     29814
# gender                      0
# nationality                 0
# accident_cause_code         0
# accident_cause              0
# vehicle_type                0
# province_th                 0
# district_th                 0
# sub_district_th             0
# province_en                 0
# district_en                 0
# sub_district_en             0
# latitude                    0
# longitude                   0
# dtype: int64

# %%
df.describe()
df.describe(include='all')
# Out:
#               accident_date official_death_date            age  gender  \
# count                106950              240924  211110.000000  240924
# unique                91871                4383            NaN       3
# top     2017-01-02 13:50:00          2012-01-01            NaN    Male
# freq                     14                 137            NaN  184157
# mean                    NaN                 NaN      39.945531     NaN
# std                     NaN                 NaN      19.890274     NaN
# min                     NaN                 NaN     -22.000000     NaN
# 25%                     NaN                 NaN      23.000000     NaN
# 50%                     NaN                 NaN      38.000000     NaN
# 75%                     NaN                 NaN      55.000000     NaN
# max                     NaN                 NaN     154.000000     NaN
#
#        nationality accident_cause_code  \
# count       240924              240924
# ...

# %%
df.duplicated().sum()    # how many duplicate rows exist
# Out:
# np.int64(2478)

# %%
print("Before:", df.shape)               # check before
df = df.drop_duplicates()                # remove duplicates
print("After:", df.shape)                # check after
print("Duplicates left:", df.duplicated().sum())  # should be 0
# Out:
# Before: (240924, 16)
# After: (238446, 16)
# Duplicates left: 0

# %%
df.isnull().sum()
# Out:
# accident_date          132022
# official_death_date         0
# age                     27887
# gender                      0
# nationality                 0
# accident_cause_code         0
# accident_cause              0
# vehicle_type                0
# province_th                 0
# district_th                 0
# sub_district_th             0
# province_en                 0
# district_en                 0
# sub_district_en             0
# latitude                    0
# longitude                   0
# dtype: int64

# %%
df["age"] = df["age"].fillna(df["age"].median())
df["age"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["age"].describe()
# Out:
# count    238446.000000
# mean         39.746270
# std          18.692666
# min         -22.000000
# 25%          25.000000
# 50%          38.000000
# 75%          52.000000
# max         154.000000
# Name: age, dtype: float64

# %%
df = df[(df["age"] >= 0) & (df["age"] <= 120)]
df["age"].describe()
# Out:
# count    237936.000000
# mean         39.554842
# std          18.235797
# min           0.000000
# 25%          25.000000
# 50%          38.000000
# 75%          52.000000
# max         119.000000
# Name: age, dtype: float64

# %%
df.isnull().sum()
# Out:
# accident_date          132020
# official_death_date         0
# age                         0
# gender                      0
# nationality                 0
# accident_cause_code         0
# accident_cause              0
# vehicle_type                0
# province_th                 0
# district_th                 0
# sub_district_th             0
# province_en                 0
# district_en                 0
# sub_district_en             0
# latitude                    0
# longitude                   0
# dtype: int64

# %%
df = df.drop_duplicates()
df.duplicated().sum()    # should now print 0
# Out:
# np.int64(0)

# %%
df["gender"].value_counts()
# Out:
# gender
# Male       181898
# Female      49547
# Unknown      6487
# Name: count, dtype: int64

# %%
df["nationality"].value_counts()
# Out:
# nationality
# Thai                     132239
# Unknown                  105434
# Burmese                     127
# Cambodian                    27
# Lao Laotian                  17
# Beninese                     15
# Malian                        6
# British Briton                4
# German                        3
# Macedonian                    3
# Japanese                      3
# French                        3
# Australian                    3
# Chinese                       3
# Malaysian                     3
# Colombian                     3
# Bahamian                      3
# Dutch Dutchman                2
# Norwegian                     2
# American                      2
# Icelander                     2
# Malawian                      2
# Afghan                        2
# Russian                       2
# Bosnian Herzegovinian         1
# Danish Dane                   1
# Yemeni                        1
# Swazi                         1
# Italian                       1
# ...

# %%
df["vehicle_type"].value_counts()
# Out:
# vehicle_type
# unidentified            111695
# moterbike                94637
# car                      17397
# pedestrian                7420
# small_truck_or_van        4015
# bike                      1126
# hevay_truck                884
# tricycle                   376
# bus                        288
# agricultural_vehicle        94
# Name: count, dtype: int64

# %%
df["vehicle_type"] = df["vehicle_type"].replace({"moterbike": "motorbike", "hevay_truck" : "heavy_truck",})
#Confirm the fix
df["vehicle_type"].value_counts()
# Out:
# vehicle_type
# unidentified            111695
# motorbike                94637
# car                      17397
# pedestrian                7420
# small_truck_or_van        4015
# bike                      1126
# heavy_truck                884
# tricycle                   376
# bus                        288
# agricultural_vehicle        94
# Name: count, dtype: int64

# %%
#Save clean data
df.to_csv("data/clean_data.csv", index=False)
